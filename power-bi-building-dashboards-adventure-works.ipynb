# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/adventure-works-sales/AdventureWorks Returns Data.csv
# /kaggle/input/adventure-works-sales/AdventureWorks Territory Lookup.csv
# /kaggle/input/adventure-works-sales/AdventureWorks Customer Lookup.csv
# /kaggle/input/adventure-works-sales/AdventureWorks Calendar Lookup.csv
# /kaggle/input/adventure-works-sales/AdventureWorks Sales Data 2021.csv
# /kaggle/input/adventure-works-sales/AdventureWorks Product Lookup.csv
# /kaggle/input/adventure-works-sales/Product Category Sales (Unpivot Demo).csv
# /kaggle/input/adventure-works-sales/AdventureWorks Product Categories Lookup.csv
# /kaggle/input/adventure-works-sales/AdventureWorks Sales Data 2022.csv
# /kaggle/input/adventure-works-sales/AdventureWorks Sales Data 2020.csv
# /kaggle/input/adventure-works-sales/AdventureWorks Product Subcategories Lookup.csv

# %% [markdown]
# # I want to introduce my Power BI project on Adventure Works analysis and vizulization.
#
# ### At first, I'll demonstrate abilities of interactive dashboards I've creaeted and then I'll show some of measures and how raw data was looking at the beginning of the project.
#
#
# ![Снимок экрана 2023-11-30 135132.png](attachment:8a08d025-1027-4a22-b768-b04a2a04e821.png)
# ### This is the page with main dashboard, showing basic business metrics for Adventure Works. On the left side of the page you can see navigation panel on the bottom of the page (we have four dashboards total) and two buttons on the top with filtering action and returning to non-filtered page action.

# %% [markdown]
# ![Снимок экрана 2023-11-30 140440.png](attachment:4a8f14ca-66f1-4d7f-90ba-4367007cff1c.png)
# ### This screen shot demonstrates that dashboard changes information on the page interactively after choosing "Bikes" category and shows anomaly data on the line chart and its analysis using AI abilities.

# %% [markdown]
# ![Снимок экрана 2023-11-30 141411.png](attachment:08bcc7a6-211b-4106-b7d6-f90a5fe5d5a8.png)
# ### To have quick access to the short summaries of the metrics by category, I've created individual page with dashboard and attached it to the "Orders by Category" bar chart as a tooltip

# %% [markdown]
# ![Снимок экрана 2023-11-30 144829.png](attachment:87c8a650-593b-4315-98c5-04a862bbe61c.png)
# ### This is the second page and how you can easily guess, it's showing areas of the sales.

# %% [markdown]
# ![Снимок экрана 2023-11-30 145047.png](attachment:afd9c809-068d-4b5f-88c2-856e6c08834b.png)
# ### To jump on the third page of our report we can select one of the products on the table on the main page and after right click on this product choose "drill down" option.

# %% [markdown]
# ![Снимок экрана 2023-11-30 145404.png](attachment:d9ab41bb-dc6d-4ca4-902c-cf8b5b8dc6c8.png)
# ### Here's our third page of the report with product details (the exact one we chose on the first page). Here are few interesting details: "Report Summary" generated with AI and two line charts with optional settings, as "Metric Selection" and "Price Adjustment".

# %% [markdown]
# ![Снимок экрана 2023-11-30 145926.png](attachment:bcdb0369-42bd-454b-806c-ce4bd9962b4e.png)
# ### And here's the last but not least dashboard with customer detail information. We can control line chart with two metrics. We can choose a year or an series of years for this dashboard.

# %% [markdown]
# ## Now I wanna show how does model view look like and couple examples of measures that I used for building this report.

# %% [markdown]
# ![Снимок экрана 2023-11-30 150600.png](attachment:2488c672-ec12-464b-85ff-f3e61148e067.png)
# ### This is how my model view looks like and also you can look at short information about datasets that I used for this report.

# %% [markdown]
# ![Снимок экрана 2023-11-30 150845.png](attachment:075f26e7-137f-4bc3-b0a3-681f0d051258.png)
# ### I used bunch of measures for this report and here's all of them. They are all pretty simple, but let me show you couple of them that are very useful in my opinion.

# %% [markdown]
# ![Снимок экрана 2023-11-30 151118.png](attachment:52f57ceb-c222-48e1-b81d-a9d16ad23502.png)
# ![Снимок экрана 2023-11-30 151241.png](attachment:7c5c5897-3a55-47b9-9446-cf7b0e81a419.png)
# ### There's two very useful measures working perfectly together. With them we can build important charts and compare our executive metrics with previous ones and targets.
# ![image.png](attachment:ddb2568e-b1e7-45b5-ae32-943e09c7604d.png)
# ![image.png](attachment:11143cfa-41cc-4d34-9718-b4ebcd2e1f74.png)
